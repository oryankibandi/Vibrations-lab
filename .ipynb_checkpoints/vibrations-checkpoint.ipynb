# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
fig = plt.figure()
#0-0.25
nums_x = np.linspace(0,0.25,25)#creates a numpy array of equaly spaced numbers between 0 and 0.25
nums_y = np.array([])#initialize and empty numpy array
arb_listx = []
arb_listy = []
#for loop iterating the list of x values and caculating their y values
for x in nums_x:
    y=4*x
    arb_listy.append(y)#appends the value to a list
nums_y = np.append(nums_y,arb_listy)
#0.25-0.75
nums_x2 = np.linspace(0.25,0.75,50)
arb_listx = []#sets the lists to empty
arb_listy = []
for x2 in nums_x2:
    #nums_x3 = np.append(nums_x,x2)
    arb_listx.append(x2)
    y2 = (-4*x2)+2
    arb_listy.append(y2)
    #print('y:',y2)
#plt.plot(nums_x,nums_y)
#update the array by appending the values in the list to ut
nums_x = np.append(nums_x,arb_listx)
nums_y = np.append(nums_y,arb_listy)
arb_listx = []
arb_listy = []
#0.75-1
nums_x3 = np.linspace(0.75,1,25)
for x3 in nums_x3:
    arb_listx.append(x3)
    y3 = (4*x3)-4
    arb_listy.append(y3)
nums_x = np.append(nums_x,arb_listx)
nums_y = np.append(nums_y,arb_listy)
plt.plot(nums_x,nums_y)
